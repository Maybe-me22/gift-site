# %%
print("hello I'm hameed") 
print("I'm a programmer") 
print("I'm from yemen, from taiz")
print("I have 21 years old")
print("مااحلم به اليوم سوف يصبح حقيقة في الغد ماالمشكله في الفشل إن لم نحاول النهوض ولكن بيدي سوف اصل بإذن الله") 
print("ـــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــــ") 

print("يرجى تعبئة السيره الذاتية. ")
attempts = 0
while True: 
    try: 
        admin=int(input("أدخل كلمه المرور:"))
        if admin == 123:
            print("اهلا وسهلا بك")
            break 
        else: 
                print("الرمز الذي ادخلته غير صحيح")
                break
        attempts += 1
        if attempts == 3:
               print("لقد تم حظرك لعدد المحاولات الخاطئة ")                           
               exit() 
    except ValueError:
        print("كلمه المرور خاصة بنا")
        attempts += 1
        if attempts ==3:
            print:("لقد تم حظرك لعدد المحاولات الخاطئة")
            exit()                      
name= input("الإسم: ")
last_name= input("اللقب: ")
while True: 
    try: 
        age= int(input("العمر: "))
        if age  <= 0:
            print("العمر لايمكن ان يكون سالباً حاول مرةً اخرى. ")
            continue
        break
    except ValueError: 
        print("الرجاء إدخال عدد صحيح فقط (بدون فواصل أو حروف).")
if age  >= 60:
    print("العمر يتجاوز السن المطلوب. ")
    exit()
elif age  >= 18:
    print("العمر المطلوب صحيح ✅")
else:
    print("عمرك لا يتجاوز السن القانوني ❌")
    exit()
retirement_age= 60
years_left= retirement_age - age
print("يتبقى لك ",years_left,"سنه للتقاعد")

gender= input("الجنس ذكر  / انثى: ")
if gender ==  "انثى": 
    print("انثى🙋🏻‍♀️")
elif gender ==  "ذكر":
     print("ذكر🙋🏻‍")
else: 
    print("جنس غير معروف! ✋🏻")
nationality= input("الجنسية: ")
while True:
    phone= input("أدخل رقم الهاتف(يجب أن يبدأ ب+967):").strip()
    if phone.startswith("+967") and phone[4:]. isdigit(): 
        print("✅تم قبول الرقم", phone)    
        break
    else: 
        print("الرقم غير صحيح❌، تأكد أن يبدأ ب+967 وأن يحتوي على أرقام فقط. ")
while True: 
    email= input("أدخل بريدك الإلكتروني: ").strip()       
    if "@" in email and "." in email: 
        print ("بريد الإلكتروني صحيح")
        break
    else:
          print("البريد غير صحيح، تأكد من كتابته بشكل صحيح. ")
education= input ("ماهو مؤهلك الدراسي؟[جامعي، ثانوي، دبلوم... الخ] ")
experiences= input("ماهي خبراتك؟[ الخبرات قد تزيد من مستوى قبولك في العمل] ").strip()
skills= input("ماهي المهارات التي تمتلكها؟[ مهاراتك قد تزيد من احتمالية قبولك] ").strip()
languages= input("ماهي اللغات التي تمتلكها؟ ").strip()

print ("\n🔖 السيرة الذاتية الخاص بك: ")
print(f"الاسم الكامل: {name} {last_name}")
print(f"العمر: {age}")
print(f"الجنس: {gender}")
print(f"رقم الهاتف: {phone}")
print(f"الجنسية: {nationality}")
print(f"البريد الإلكتروني: {email}")
print(f"المؤهل الدراسي: {education}")
print(f"الخبرات: {experiences}")
print(f"المهارات: {skills}")
print(f"اللغات التي تمتلكها: {languages}")
print(f"سنوات متبقيه للتقاعد: {years_left}")


print("برمجيات: حميد السامعي")
print("[اتمنى لكم مزيداً من التوفيق والنجاح في مسيرتكم العلميه والعملية] ")
